# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import List
import os

import seaborn as sns
import plotly.express as px
from tqdm import tqdm

from openai import AzureOpenAI
from openai import OpenAI

from openai_utils import *

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 100)

# %%
# Load keys
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Directory setup
data_dir = "../data/"
output_dir = "../results/general_knowledge/"

os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Generate Questions

# %%
def load_and_process_data(file_path):
    # Load the data
    df = pd.read_csv(file_path)

    # Filter out rows that are not "preferred name" or "brand name"
    filtered_df = df[df["string_type"].isin(["preferred name", "brand name"])]

    # Group by concept_code and keep the first occurrence of each string_type per group
    unique_names_df = (
        filtered_df.groupby(["concept_code", "string_type"]).first().reset_index()
    )

    # Since we want to keep one of each type per concept_code, let's ensure there's only one of each
    final_df = unique_names_df.groupby("concept_code").filter(lambda x: len(x) <= 2)

    # Filter out concept_codes that appear only once in the DataFrame
    counts = final_df["concept_code"].value_counts()
    filtered_final_df = final_df[
        final_df["concept_code"].isin(counts[counts > 1].index)
    ]

    # Ensure we have a DataFrame that includes both a preferred name and a brand name for each concept_code
    concept_codes_with_both_names = filtered_final_df.groupby("concept_code").filter(
        lambda x: len(x) == 2
    )

    # Split the DataFrame into two: one for preferred names and one for brand names
    preferred_names_df = concept_codes_with_both_names[
        concept_codes_with_both_names["string_type"] == "preferred name"
    ]

    brand_names_df = concept_codes_with_both_names[
        concept_codes_with_both_names["string_type"] == "brand name"
    ]

    # Merge them to have a single DataFrame with both preferred and brand names for each concept_code
    combined_df = pd.merge(
        preferred_names_df,
        brand_names_df,
        on="concept_code",
        suffixes=("_preferred", "_brand"),
    )

    return combined_df


combined_df = load_and_process_data(data_dir + "HemOnc_drug_list.csv")

combined_df
# Out:
#      concept_code string_type_preferred  Unnamed: 0_preferred  \
# 0               4        preferred name                     8
# 1               6        preferred name                    14
# 2               7        preferred name                    39
# 3               9        preferred name                    49
# 4              12        preferred name                   105
# ..            ...                   ...                   ...
# 362        111358        preferred name                  6057
# 363        111427        preferred name                  6063
# 364        114346        preferred name                  6072
# 365        114432        preferred name                  6084
# 366        114494        preferred name                  6094
#
#           string_preferred string_type_brand  Unnamed: 0_brand string_brand
# 0              Abemaciclib        brand name                10     Verzenio
# 1              Abiraterone        brand name                17     Abatitor
# 2            Acalabrutinib        brand name                41    Calquence
# 3              Aclarubicin        brand name                56      Aclacin
# 4    Trastuzumab emtansine        brand name               110      Kadcyla
# ..                     ...               ...               ...          ...
# 362           Olutasidenib        brand name              6059    Rezlidhia
# 363              Pyrotinib        brand name              6064        Irene
# 364              Buserelin        brand name              6076     Bigonist
# 365            Lifileuecel        brand name              6086      Contego
# 366          Tabelecleucel        brand name              6097      Ebvallo
#
# [367 rows x 7 columns]

# %%
# Save the combined DataFrame
combined_df.to_csv(data_dir + "combined_df.csv", index=False)

# %%
all_preferred_names = combined_df["string_preferred"].unique()
all_brand_names = combined_df["string_brand"].unique()

# %%
# Function to generate three random incorrect answers
def get_incorrect_answers(correct_answer, all_answers):
    incorrect_answers = np.random.choice(
        all_answers[all_answers != correct_answer], size=3, replace=False
    )
    return incorrect_answers.tolist()


def generate_variations(
    all_answers,
    correct_answer,
    question_template,
    concept_code,
    variation_id,
    num_variations=5,
):
    incorrect_answers = get_incorrect_answers(correct_answer, all_answers)
    options = [correct_answer] + incorrect_answers
    np.random.shuffle(options)  # Shuffle all options
    return {
        "concept_code": concept_code,
        "variation_id": variation_id,
        "question": question_template,
        "options": options,
        "correct_answer": correct_answer,
    }

# %%
# Generate questions and answers
questions_answers = []
num_variations = 5

for index, row in combined_df.iterrows():
    concept_code = row["concept_code"]
    preferred_name = row["string_preferred"]
    brand_name = row["string_brand"]

    for variation_id in range(1, 6):  # Generate 5 variations
        # Brand name question variations
        question_brand_template = (
            f"Which of the following is the brand name for the drug {preferred_name}?"
        )
        variation_brand = generate_variations(
            all_brand_names,
            brand_name,
            question_brand_template,
            concept_code,
            variation_id,
            num_variations,
        )
        questions_answers.append(variation_brand)

        # Generic name question variations
        question_generic_template = (
            f"Which of the following is the generic name for the drug {brand_name}?"
        )
        variation_generic = generate_variations(
            all_preferred_names,
            preferred_name,
            question_generic_template,
            concept_code,
            variation_id,
        )
        questions_answers.append(variation_generic)

# Preview the first few questions and answers
questions_answers[:10]
# Out:
# [{'concept_code': 4,
#   'variation_id': 1,
#   'question': 'Which of the following is the brand name for the drug Abemaciclib?',
#   'options': ['Verzenio', 'Gemcite', 'Artinizona', 'Nubeqa'],
#   'correct_answer': 'Verzenio'},
#  {'concept_code': 4,
#   'variation_id': 1,
#   'question': 'Which of the following is the generic name for the drug Verzenio?',
#   'options': ['Abemaciclib',
#    'Apalutamide',
#    'Vindesine',
#    'Trifluridine and tipiracil'],
#   'correct_answer': 'Abemaciclib'},
#  {'concept_code': 4,
#   'variation_id': 2,
#   'question': 'Which of the following is the brand name for the drug Abemaciclib?',
#   'options': ['Marqibo', 'Bavencio', 'Longastatina', 'Verzenio'],
#   'correct_answer': 'Verzenio'},
#  {'concept_code': 4,
#   'variation_id': 2,
#   'question': 'Which of the following is the generic name for the drug Verzenio?',
#   'options': ['Tamibarotene', 'Amonafide', 'Zidovudine', 'Abemaciclib'],
#   'correct_answer': 'Abemaciclib'},
#  {'concept_code': 4,
#   'variation_id': 3,
#   'question': 'Which of the following is the brand name for the drug Abemaciclib?',
#   'options': ['Verzenio', 'Campath', 'CA ATRA', 'Amekrin'],
#   'correct_answer': 'Verzenio'},
#  {'concept_code': 4,
#   'variation_id': 3,
#   'question': 'Which of the following is the generic name for the drug Verzenio?',
#   'options': ['Amsacrine', 'Trametinib', 'Abemaciclib', 'Dinutuximab'],
#   'correct_answer': 'Abemaciclib'},
#  {'concept_code': 4,
#   'variation_id': 4,
#   'question': 'Which of the following is the brand name for the drug Abemaciclib?',
#   'options': ['Tyvyt', 'Rafinlar', 'Verzenio', 'Tasigna'],
#   'correct_answer': 'Verzenio'},
#  {'concept_code': 4,
#   'variation_id': 4,
#   'question': 'Which of the following is the generic name for the drug Verzenio?',
#   'options': ['Nintedanib', 'Sipuleucel-T', 'Pentostatin', 'Abemaciclib'],
#   'correct_answer': 'Abemaciclib'},
#  {'concept_code': 4,
#   'variation_id': 5,
#   'question': 'Which of the following is the brand name for the drug Abemaciclib?',
#   'options': ['Cejemly', 'Kymriah', 'Erleada', 'Verzenio'],
#   'correct_answer': 'Verzenio'},
#  {'concept_code': 4,
#   'variation_id': 5,
#   'question': 'Which of the following is the generic name for the drug Verzenio?',
#   'options': ['Sorafenib', 'Ceritinib', 'Abemaciclib', 'Camrelizumab'],
#   'correct_answer': 'Abemaciclib'}]

# %%
# Create a DataFrame from the questions_answers list
qa_df = pd.DataFrame(questions_answers)

# Include variation_id in your qa_brand_df and qa_preferred_df before merging
qa_brand_df = qa_df[
    qa_df["question"].str.contains("brand name for the drug")
].reset_index(drop=True)

qa_preferred_df = qa_df[
    qa_df["question"].str.contains("generic name for the drug")
].reset_index(drop=True)

# %%
# Create a new DataFrame that repeats each row of combined_df for each variation
expanded_combined_df = pd.DataFrame(
    np.repeat(combined_df.values, num_variations, axis=0), columns=combined_df.columns
)

# Add a variation_id column to expanded_combined_df
expanded_combined_df["variation_id"] = np.tile(
    np.arange(1, num_variations + 1), len(combined_df)
)

expanded_combined_df
# Out:
#      concept_code string_type_preferred Unnamed: 0_preferred string_preferred  \
# 0               4        preferred name                    8      Abemaciclib
# 1               4        preferred name                    8      Abemaciclib
# 2               4        preferred name                    8      Abemaciclib
# 3               4        preferred name                    8      Abemaciclib
# 4               4        preferred name                    8      Abemaciclib
# ...           ...                   ...                  ...              ...
# 1830       114494        preferred name                 6094    Tabelecleucel
# 1831       114494        preferred name                 6094    Tabelecleucel
# 1832       114494        preferred name                 6094    Tabelecleucel
# 1833       114494        preferred name                 6094    Tabelecleucel
# 1834       114494        preferred name                 6094    Tabelecleucel
#
#      string_type_brand Unnamed: 0_brand string_brand  variation_id
# 0           brand name               10     Verzenio             1
# 1           brand name               10     Verzenio             2
# 2           brand name               10     Verzenio             3
# 3           brand name               10     Verzenio             4
# 4           brand name               10     Verzenio             5
# ...                ...              ...          ...           ...
# 1830        brand name             6097      Ebvallo             1
# 1831        brand name             6097      Ebvallo             2
# 1832        brand name             6097      Ebvallo             3
# 1833        brand name             6097      Ebvallo             4
# 1834        brand name             6097      Ebvallo             5
#
# [1835 rows x 8 columns]

# %%
# Merging with combined_df, ensuring variation_id is kept
filtered_final_df_with_qa = pd.merge(
    expanded_combined_df,
    qa_brand_df,
    on=["concept_code", "variation_id"],
    how="left",
    suffixes=("_brand", ""),
)

filtered_final_df_with_qa = pd.merge(
    filtered_final_df_with_qa,
    qa_preferred_df,
    on=["concept_code", "variation_id"],
    how="left",
    suffixes=("_brand", "_preferred"),
)

filtered_final_df_with_qa
# Out:
#      concept_code string_type_preferred Unnamed: 0_preferred string_preferred  \
# 0               4        preferred name                    8      Abemaciclib
# 1               4        preferred name                    8      Abemaciclib
# 2               4        preferred name                    8      Abemaciclib
# 3               4        preferred name                    8      Abemaciclib
# 4               4        preferred name                    8      Abemaciclib
# ...           ...                   ...                  ...              ...
# 1830       114494        preferred name                 6094    Tabelecleucel
# 1831       114494        preferred name                 6094    Tabelecleucel
# 1832       114494        preferred name                 6094    Tabelecleucel
# 1833       114494        preferred name                 6094    Tabelecleucel
# 1834       114494        preferred name                 6094    Tabelecleucel
#
#      string_type_brand Unnamed: 0_brand string_brand  variation_id  \
# 0           brand name               10     Verzenio             1
# 1           brand name               10     Verzenio             2
# 2           brand name               10     Verzenio             3
# 3           brand name               10     Verzenio             4
# 4           brand name               10     Verzenio             5
# ...                ...              ...          ...           ...
# 1830        brand name             6097      Ebvallo             1
# 1831        brand name             6097      Ebvallo             2
# 1832        brand name             6097      Ebvallo             3
# 1833        brand name             6097      Ebvallo             4
# 1834        brand name             6097      Ebvallo             5
#
#                                                             question_brand  \
# 0       Which of the following is the brand name for the drug Abemaciclib?
# 1       Which of the following is the brand name for the drug Abemaciclib?
# 2       Which of the following is the brand name for the drug Abemaciclib?
# 3       Which of the following is the brand name for the drug Abemaciclib?
# 4       Which of the following is the brand name for the drug Abemaciclib?
# ...                                                                    ...
# 1830  Which of the following is the brand name for the drug Tabelecleucel?
# 1831  Which of the following is the brand name for the drug Tabelecleucel?
# 1832  Which of the following is the brand name for the drug Tabelecleucel?
# 1833  Which of the following is the brand name for the drug Tabelecleucel?
# 1834  Which of the following is the brand name for the drug Tabelecleucel?
#
#                                         options_brand correct_answer_brand  \
# 0             [Verzenio, Gemcite, Artinizona, Nubeqa]             Verzenio
# 1         [Marqibo, Bavencio, Longastatina, Verzenio]             Verzenio
# 2               [Verzenio, Campath, CA ATRA, Amekrin]             Verzenio
# 3                [Tyvyt, Rafinlar, Verzenio, Tasigna]             Verzenio
# 4               [Cejemly, Kymriah, Erleada, Verzenio]             Verzenio
# ...                                               ...                  ...
# 1830  [Qualaquin, Inrebic, Ebvallo, Longastatina LAR]              Ebvallo
# 1831           [Anandron, Colcrys, Ebvallo, Lynparza]              Ebvallo
# 1832          [Welireg, Ebvallo, Contergan, Yescarta]              Ebvallo
# 1833         [Tukysa, Pepto-Bismol, Dacogen, Ebvallo]              Ebvallo
# 1834              [Femara, Bosulif, Besremi, Ebvallo]              Ebvallo
#
#                                                      question_preferred  \
# 0     Which of the following is the generic name for the drug Verzenio?
# 1     Which of the following is the generic name for the drug Verzenio?
# 2     Which of the following is the generic name for the drug Verzenio?
# 3     Which of the following is the generic name for the drug Verzenio?
# 4     Which of the following is the generic name for the drug Verzenio?
# ...                                                                 ...
# 1830   Which of the following is the generic name for the drug Ebvallo?
# 1831   Which of the following is the generic name for the drug Ebvallo?
# 1832   Which of the following is the generic name for the drug Ebvallo?
# 1833   Which of the following is the generic name for the drug Ebvallo?
# 1834   Which of the following is the generic name for the drug Ebvallo?
#
#                                                            options_preferred  \
# 0          [Abemaciclib, Apalutamide, Vindesine, Trifluridine and tipiracil]
# 1                         [Tamibarotene, Amonafide, Zidovudine, Abemaciclib]
# 2                          [Amsacrine, Trametinib, Abemaciclib, Dinutuximab]
# 3                       [Nintedanib, Sipuleucel-T, Pentostatin, Abemaciclib]
# 4                          [Sorafenib, Ceritinib, Abemaciclib, Camrelizumab]
# ...                                                                      ...
# 1830                        [Tabelecleucel, Vindesine, Carmustine, Thiotepa]
# 1831                     [Tabelecleucel, Lansoprazole, Valrubicin, Afatinib]
# 1832                 [Dacarbazine, Selumetinib, Tabelecleucel, Sargramostim]
# 1833                        [Etoposide, Buserelin, Tabelecleucel, Cediranib]
# 1834  [Panobinostat, Interferon alfa-2b, Polatuzumab vedotin, Tabelecleucel]
#
#      correct_answer_preferred
# 0                 Abemaciclib
# 1                 Abemaciclib
# 2                 Abemaciclib
# 3                 Abemaciclib
# 4                 Abemaciclib
# ...                       ...
# 1830            Tabelecleucel
# 1831            Tabelecleucel
# 1832            Tabelecleucel
# 1833            Tabelecleucel
# 1834            Tabelecleucel
#
# [1835 rows x 14 columns]

# %%
def generate_name_questions(row):
    questions = {}

    for type in ["preferred", "brand"]:
        question_type_key = f"question_{type}"
        options_type_key = f"options_{type}"

        question = row[question_type_key]
        options = row[options_type_key]

        # Check if options is already a list, if not attempt to interpret it as such
        if not isinstance(options, list):
            options_list = options.split(",") if isinstance(options, str) else []
        else:
            options_list = options

        options_formatted = ", ".join(
            [f"{i + 1}: {opt.strip()}" for i, opt in enumerate(options_list)]
        )

        final_question = f"{question}\nOptions: {options_formatted}\nAnswer: {row['correct_answer_' + type]}"
        questions[type] = final_question

    return questions["preferred"], questions["brand"]


# Apply the updated function and create new columns for preferred and brand questions
filtered_final_df_with_qa[["final_preferred_question", "final_brand_question"]] = (
    filtered_final_df_with_qa.apply(
        lambda row: generate_name_questions(row), axis=1, result_type="expand"
    )
)

# preview the final DataFrame
print(
    filtered_final_df_with_qa[
        ["final_preferred_question", "final_brand_question"]
    ].head()
)
# Out:
#                                                                                                                                                        final_preferred_question  \
# 0  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Abemaciclib, 2: Apalutamide, 3: Vindesine, 4: Trifluridine and tipiracil\nAnswer: Abemaciclib
# 1                 Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Tamibarotene, 2: Amonafide, 3: Zidovudine, 4: Abemaciclib\nAnswer: Abemaciclib
# 2                  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Amsacrine, 2: Trametinib, 3: Abemaciclib, 4: Dinutuximab\nAnswer: Abemaciclib
# 3               Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Nintedanib, 2: Sipuleucel-T, 3: Pentostatin, 4: Abemaciclib\nAnswer: Abemaciclib
# 4                  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Sorafenib, 2: Ceritinib, 3: Abemaciclib, 4: Camrelizumab\nAnswer: Abemaciclib
#
#                                                                                                                                    final_brand_question
# 0      Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Verzenio, 2: Gemcite, 3: Artinizona, 4: Nubeqa\nAnswer: Verzenio
# 1  Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Marqibo, 2: Bavencio, 3: Longastatina, 4: Verzenio\nAnswer: Verzenio
# 2        Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Verzenio, 2: Campath, 3: CA ATRA, 4: Amekrin\nAnswer: Verzenio
# 3         Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Tyvyt, 2: Rafinlar, 3: Verzenio, 4: Tasigna\nAnswer: Verzenio
# 4        Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Cejemly, 2: Kymriah, 3: Erleada, 4: Verzenio\nAnswer: Verzenio

# %% [markdown]
# ## GPT Inference

# %%
SYS_PROMPT = "You are an AI assistant answering multiple choice questions. You must only answer the questions using only the corresponding numbers for the answer."
SERVICE = "openai"
temperatures = [0.0, 1.0, 2.0]

# %%
# ################ DEBUG ################
# filtered_final_df_with_qa = filtered_final_df_with_qa.head()

# %%
# Dict for storing DataFrames for each temperature
temperature_dfs = {}

for temp in temperatures:
    # Lists for storing inference results for the current temperature
    inferred_preferred_names = []
    inferred_brand_names = []

    # Get inference for each row in the DataFrame
    for index, row in tqdm(
        filtered_final_df_with_qa.iterrows(),
        total=filtered_final_df_with_qa.shape[0],
        desc=f"Temperature {temp}",
    ):
        # Handle preferred name question
        preferred_question = row["final_preferred_question"]
        response_preferred = get_chat_completion(
            user_prompt=preferred_question,
            system_prompt=SYS_PROMPT,
            service=SERVICE,
            temperature=temp,
            max_tokens=1,
            full_response=True,
        )
        inferred_preferred_names.append(response_preferred)

        # Handle brand name question
        brand_question = row["final_brand_question"]
        response_brand = get_chat_completion(
            user_prompt=brand_question,
            system_prompt=SYS_PROMPT,
            service=SERVICE,
            temperature=temp,
            max_tokens=1,
            full_response=True,
        )
        inferred_brand_names.append(response_brand)

    # Create a new DataFrame for the current temperature
    temp_df = filtered_final_df_with_qa.copy()
    temp_df["inferred_preferred_name"] = inferred_preferred_names
    temp_df["inferred_brand_name"] = inferred_brand_names

    # Apply digit extraction based on the SERVICE
    if SERVICE == "azure":
        temp_df["inferred_preferred_answer"] = [
            extract_azure_top_digit(i) for i in temp_df["inferred_preferred_name"]
        ]
        temp_df["inferred_brand_answer"] = [
            extract_azure_top_digit(i) for i in temp_df["inferred_brand_name"]
        ]
    else:
        temp_df["inferred_preferred_answer"] = [
            extract_openai_top_digit(i) for i in temp_df["inferred_preferred_name"]
        ]
        temp_df["inferred_brand_answer"] = [
            extract_openai_top_digit(i) for i in temp_df["inferred_brand_name"]
        ]

    # Store the DataFrame in the dictionary with a key representing the temperature
    temperature_dfs[f"temp_{str(temp).replace('.', '_')}"] = temp_df

# Print keys in the dictionary
print(temperature_dfs.keys())

# Preview the DataFrame for a temperature
temperature_dfs["temp_0_8"]
# Out:
# Temperature 0: 100%|██████████| 5/5 [00:03<00:00,  1.36it/s]
# Temperature 0.8: 100%|██████████| 5/5 [00:03<00:00,  1.57it/s]
# dict_keys(['temp_0', 'temp_0_8'])
#   concept_code string_type_preferred Unnamed: 0_preferred string_preferred  \
# 0            4        preferred name                    8      Abemaciclib
# 1            4        preferred name                    8      Abemaciclib
# 2            4        preferred name                    8      Abemaciclib
# 3            4        preferred name                    8      Abemaciclib
# 4            4        preferred name                    8      Abemaciclib
#
#   string_type_brand Unnamed: 0_brand string_brand  variation_id  \
# 0        brand name               10     Verzenio             1
# 1        brand name               10     Verzenio             2
# 2        brand name               10     Verzenio             3
# 3        brand name               10     Verzenio             4
# 4        brand name               10     Verzenio             5
#
#                                                        question_brand  \
# 0  Which of the following is the brand name for the drug Abemaciclib?
# 1  Which of the following is the brand name for the drug Abemaciclib?
# 2  Which of the following is the brand name for the drug Abemaciclib?
# 3  Which of the following is the brand name for the drug Abemaciclib?
# 4  Which of the following is the brand name for the drug Abemaciclib?
#
#                                  options_brand correct_answer_brand  \
# 0      [Verzenio, Gemcite, Artinizona, Nubeqa]             Verzenio
# 1  [Marqibo, Bavencio, Longastatina, Verzenio]             Verzenio
# 2        [Verzenio, Campath, CA ATRA, Amekrin]             Verzenio
# 3         [Tyvyt, Rafinlar, Verzenio, Tasigna]             Verzenio
# 4        [Cejemly, Kymriah, Erleada, Verzenio]             Verzenio
#
#                                                   question_preferred  \
# 0  Which of the following is the generic name for the drug Verzenio?
# 1  Which of the following is the generic name for the drug Verzenio?
# 2  Which of the following is the generic name for the drug Verzenio?
# 3  Which of the following is the generic name for the drug Verzenio?
# 4  Which of the following is the generic name for the drug Verzenio?
#
#                                                    options_preferred  \
# 0  [Abemaciclib, Apalutamide, Vindesine, Trifluridine and tipiracil]
# 1                 [Tamibarotene, Amonafide, Zidovudine, Abemaciclib]
# 2                  [Amsacrine, Trametinib, Abemaciclib, Dinutuximab]
# 3               [Nintedanib, Sipuleucel-T, Pentostatin, Abemaciclib]
# 4                  [Sorafenib, Ceritinib, Abemaciclib, Camrelizumab]
#
#   correct_answer_preferred  \
# 0              Abemaciclib
# 1              Abemaciclib
# 2              Abemaciclib
# 3              Abemaciclib
# 4              Abemaciclib
#
#                                                                                                                                                        final_preferred_question  \
# 0  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Abemaciclib, 2: Apalutamide, 3: Vindesine, 4: Trifluridine and tipiracil\nAnswer: Abemaciclib
# 1                 Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Tamibarotene, 2: Amonafide, 3: Zidovudine, 4: Abemaciclib\nAnswer: Abemaciclib
# 2                  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Amsacrine, 2: Trametinib, 3: Abemaciclib, 4: Dinutuximab\nAnswer: Abemaciclib
# 3               Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Nintedanib, 2: Sipuleucel-T, 3: Pentostatin, 4: Abemaciclib\nAnswer: Abemaciclib
# 4                  Which of the following is the generic name for the drug Verzenio?\nOptions: 1: Sorafenib, 2: Ceritinib, 3: Abemaciclib, 4: Camrelizumab\nAnswer: Abemaciclib
#
#                                                                                                                                    final_brand_question  \
# 0      Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Verzenio, 2: Gemcite, 3: Artinizona, 4: Nubeqa\nAnswer: Verzenio
# 1  Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Marqibo, 2: Bavencio, 3: Longastatina, 4: Verzenio\nAnswer: Verzenio
# 2        Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Verzenio, 2: Campath, 3: CA ATRA, 4: Amekrin\nAnswer: Verzenio
# 3         Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Tyvyt, 2: Rafinlar, 3: Verzenio, 4: Tasigna\nAnswer: Verzenio
# 4        Which of the following is the brand name for the drug Abemaciclib?\nOptions: 1: Cejemly, 2: Kymriah, 3: Erleada, 4: Verzenio\nAnswer: Verzenio
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       inferred_preferred_name  \
# 0  ChatCompletion(id='chatcmpl-9BVzXhYSVX7YSXalqpmRf8xeiXy6S', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.46390864, top_logprobs=[TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.46390864), TopLogprob(token='1', bytes=[49], logprob=-1.072721), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-3.5488563), TopLogprob(token='2', bytes=[50], logprob=-9.0871935), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-9.545438)])]), message=ChatCompletionMessage(content='Answer', role='assistant', function_call=None, tool_calls=None))], created=1712531611, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=97, total_tokens=98))
# 1                                     ChatCompletion(id='chatcmpl-9BVzYjZZfvHs98vtVRo4owlfzz4DM', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='4', bytes=[52], logprob=-0.49121734, top_logprobs=[TopLogprob(token='4', bytes=[52], logprob=-0.49121734), TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.9825866), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.3039517), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-9.711162), TopLogprob(token='1', bytes=[49], logprob=-9.818616)])]), message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None))], created=1712531612, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=93, total_tokens=94))
# 2     ChatCompletion(id='chatcmpl-9BVzYjfieDL9wMy4835eNhhyixvPF', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.5905365, top_logprobs=[TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.5905365), TopLogprob(token='3', bytes=[51], logprob=-0.8172344), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-5.529095), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-8.899208), TopLogprob(token='1', bytes=[49], logprob=-9.721319)])]), message=ChatCompletionMessage(content='Answer', role='assistant', function_call=None, tool_calls=None))], created=1712531612, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=93, total_tokens=94))
# 3                                   ChatCompletion(id='chatcmpl-9BVzZf3bItnM0S15Rf6EMMW3FWqPR', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='4', bytes=[52], logprob=-0.11947665, top_logprobs=[TopLogprob(token='4', bytes=[52], logprob=-0.11947665), TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-2.2473013), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.9882627), TopLogprob(token='1', bytes=[49], logprob=-10.571039), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-10.884155)])]), message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None))], created=1712531613, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=93, total_tokens=94))
# 4                                        ChatCompletion(id='chatcmpl-9BVza88vkCi2IgiTjKaUvfMFoSiwm', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='3', bytes=[51], logprob=-0.5880144, top_logprobs=[TopLogprob(token='3', bytes=[51], logprob=-0.5880144), TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.82719404), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-4.96142), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-9.123198), TopLogprob(token='2', bytes=[50], logprob=-9.921967)])]), message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None))], created=1712531614, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=90, total_tokens=91))
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      inferred_brand_name  \
# 0  ChatCompletion(id='chatcmpl-9BVzYF3WsKH4YQj28k3Y1Buh6EnvV', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.6090764, top_logprobs=[TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.6090764), TopLogprob(token='1', bytes=[49], logprob=-0.96363723), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-2.6028013), TopLogprob(token='Ver', bytes=[86, 101, 114], logprob=-8.735005), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-8.819798)])]), message=ChatCompletionMessage(content='Answer', role='assistant', function_call=None, tool_calls=None))], created=1712531612, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=86, total_tokens=87))
# 1                                                                               ChatCompletion(id='chatcmpl-9BVzYmGpcYHAUwex8CCvDCMOmaGQr', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='4', bytes=[52], logprob=-0.28532812, top_logprobs=[TopLogprob(token='4', bytes=[52], logprob=-0.28532812), TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-1.6049082), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-3.0548594), TopLogprob(token='3', bytes=[51], logprob=-9.9692), TopLogprob(token='1', bytes=[49], logprob=-10.018827)])]), message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None))], created=1712531612, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=88, total_tokens=89))
# 2   ChatCompletion(id='chatcmpl-9BVzZhVHyrDo2HRJRfaNS9ca7roo9', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.4749774, top_logprobs=[TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.4749774), TopLogprob(token='1', bytes=[49], logprob=-1.2123336), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-2.5255013), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-8.742241), TopLogprob(token='Ver', bytes=[86, 101, 114], logprob=-8.952827)])]), message=ChatCompletionMessage(content='Answer', role='assistant', function_call=None, tool_calls=None))], created=1712531613, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=86, total_tokens=87))
# 3                                                  ChatCompletion(id='chatcmpl-9BVzavi3EBzWcHZJsTel23u3X60KS', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='3', bytes=[51], logprob=-0.6077399, top_logprobs=[TopLogprob(token='3', bytes=[51], logprob=-0.6077399), TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.8678756), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-3.3434787), TopLogprob(token='Option', bytes=[79, 112, 116, 105, 111, 110], logprob=-9.501617), TopLogprob(token='2', bytes=[50], logprob=-9.952021)])]), message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None))], created=1712531614, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=87, total_tokens=88))
# 4                                ChatCompletion(id='chatcmpl-9BVzaKQ2ps1Oqa7EY9oX113xoZg9w', choices=[Choice(finish_reason='length', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.43461558, top_logprobs=[TopLogprob(token='Answer', bytes=[65, 110, 115, 119, 101, 114], logprob=-0.43461558), TopLogprob(token='4', bytes=[52], logprob=-1.1551661), TopLogprob(token='The', bytes=[84, 104, 101], logprob=-3.2919345), TopLogprob(token='Ver', bytes=[86, 101, 114], logprob=-9.167174), TopLogprob(token='1', bytes=[49], logprob=-9.83792)])]), message=ChatCompletionMessage(content='Answer', role='assistant', function_call=None, tool_calls=None))], created=1712531614, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1, prompt_tokens=88, total_tokens=89))
#
#   inferred_preferred_answer inferred_brand_answer
# 0
# 1                         4                     4
# 2
# 3                         4                     3
# 4                         3

# %% [markdown]
# ## Evaluate Performance

# %%
def calculate_accuracy(correct_answer, inferred_answer, options):
    if (
        pd.isna(inferred_answer) or inferred_answer == ""
    ):  # Check if 'inferred_answer' is empty or NaN
        return "N/A"  # Return "N/A" for not available data
    else:
        try:
            inferred_answer = int(inferred_answer)
            answer_position = options.index(correct_answer) + 1  # 1-indexed
            return "Correct" if inferred_answer == answer_position else "Incorrect"
        except ValueError:
            return "N/A"


temperature_accuracy_summaries = {}  # Store accuracy summaries for each temperature

for temp in temperatures:
    # Assuming temperature_dfs contains the DataFrames for each temperature
    temp_key = f"temp_{str(temp).replace('.', '_')}"
    temp_df = temperature_dfs[temp_key]

    # Calculate value counts for the current temperature DataFrame
    preferred_name_counts = temp_df["inferred_preferred_answer"].value_counts()
    brand_name_counts = temp_df["inferred_brand_answer"].value_counts()

    # Display the value counts for current temperature
    print(f"Temperature {temp}:")
    print("Preferred Name Value Counts:")
    print(preferred_name_counts)
    print("\nBrand Name Value Counts:")
    print(brand_name_counts)

    # Calculate accuracy
    temp_df["brand_accuracy"] = temp_df.apply(
        lambda row: calculate_accuracy(
            row["correct_answer_brand"],
            row["inferred_brand_answer"],
            row["options_brand"],
        ),
        axis=1,
    )

    temp_df["preferred_accuracy"] = temp_df.apply(
        lambda row: calculate_accuracy(
            row["correct_answer_preferred"],
            row["inferred_preferred_answer"],
            row["options_preferred"],
        ),
        axis=1,
    )

    # Creating a summary DataFrame for brand and preferred accuracies for the current temperature
    accuracy_summary = {
        "Temperature": temp,
        "Type": ["Brand", "Preferred"],
        "Correct": [
            (temp_df["brand_accuracy"] == "Correct").sum(),
            (temp_df["preferred_accuracy"] == "Correct").sum(),
        ],
        "Incorrect": [
            (temp_df["brand_accuracy"] == "Incorrect").sum(),
            (temp_df["preferred_accuracy"] == "Incorrect").sum(),
        ],
        "Not Available": [
            (temp_df["brand_accuracy"] == "N/A").sum(),
            (temp_df["preferred_accuracy"] == "N/A").sum(),
        ],
    }

    accuracy_summary_df = pd.DataFrame(accuracy_summary)
    # Store the summary DataFrame in the dictionary with a key representing the temperature
    temperature_accuracy_summaries[temp_key] = accuracy_summary_df

    # Display or store the accuracy summary DataFrame for current temperature
    print(f"\nAccuracy Summary for Temperature {temp}:")
    print(accuracy_summary_df)
# Out:
# Temperature 0:
# Preferred Name Value Counts:
# inferred_preferred_answer
#      2
# 4    2
# 3    1
# Name: count, dtype: int64
#
# Brand Name Value Counts:
# inferred_brand_answer
#      3
# 4    1
# 3    1
# Name: count, dtype: int64
#
# Accuracy Summary for Temperature 0:
#    Temperature       Type  Correct  Incorrect  Not Available
# 0            0      Brand        2          0              3
# 1            0  Preferred        3          0              2
# Temperature 0.8:
# Preferred Name Value Counts:
# inferred_preferred_answer
#      2
# 4    2
# 3    1
# Name: count, dtype: int64
#
# Brand Name Value Counts:
# inferred_brand_answer
#      3
# 4    1
# 3    1
# Name: count, dtype: int64
#
# Accuracy Summary for Temperature 0.8:
#    Temperature       Type  Correct  Incorrect  Not Available
# 0          0.8      Brand        2          0              3
# 1          0.8  Preferred        3          0              2

# %% [markdown]
# ## Save results

# %%
for temp_key, temp_df in temperature_dfs.items():
    # Save the temperature-specific DataFrame
    temp_df_filename = os.path.join(output_dir, f"{temp_key}_df.csv")
    temp_df.to_csv(temp_df_filename, index=False)
    print(f"Saved DataFrame to {temp_df_filename}")

    # Save the accuracy summary DataFrame
    summary_df = temperature_accuracy_summaries[temp_key]
    summary_df_filename = os.path.join(output_dir, f"{temp_key}_summary.csv")
    summary_df.to_csv(summary_df_filename, index=False)
    print(f"Saved Accuracy Summary to {summary_df_filename}")
# Out:
# Saved DataFrame to results/general_knowledge/temp_0_df.csv
# Saved Accuracy Summary to results/general_knowledge/temp_0_summary.csv
# Saved DataFrame to results/general_knowledge/temp_0_8_df.csv
# Saved Accuracy Summary to results/general_knowledge/temp_0_8_summary.csv
